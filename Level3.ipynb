# %% [markdown]
# ## Bandit Level 3 → Level 4
#
# The password for the next level is stored in a file called --spaces in this filename-- located in the home directory

# %% [markdown]
# - This is like the same as the previous level due to "-" as a prefix. However, the twist here is the spaces. Thus, we need to use quotation marks to read the contents of the file.

# %%
cat ./"--spaces in this filename--"

# %% [markdown]
# - The content of the file reveals the password:

# %%
MNk8KNH3Usiio41PRUEoDFPqfxLPlSmx
