# %% [markdown]
# ## Bandit Level 5 → Level 6
#
# The password for the next level is stored in a file somewhere under the inhere directory and has all of the following properties:
#
# - human-readable
# - 1033 bytes in size
# - not executable

# %% [markdown]
# - To find the file with the said properties, we can use the `find` command

# %%
find . -type f -size 1033c

# %% [markdown]
# - Now, we can find the file/s that is 1033 bytes in size.

# %%
./maybehere07/.file2

# %% [markdown]
# - Reading its content, we can find the password for the next level

# %%
HWasnPhtq9AVKe0dmk45nxy20cvUa6EG
