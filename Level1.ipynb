# %% [markdown]
# ## Bandit Level 1 → Level 2
#
# The password for the next level is stored in a file called - located in the home directory

# %% [markdown]
# - First, we need to know the contents of the current directory

# %%
ls -l

# %% [markdown]
# - Upon, executing the command, we have found that there is a file called "-"

# %%
-rw-r----- 1 bandit2 bandit1 33 Oct 14 09:26 -

# %% [markdown]
# - Since "-" as a prefix is illegal in Linux, we use the following command to read its content

# %%
cat ./-

# %% [markdown]
# - Now, we can see the password for the next level:

# %%
263JGJPfgU6LtdEvgfWU1XP5yac29mFx
