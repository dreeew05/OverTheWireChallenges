# %% [markdown]
# ## Bandit Level 3 → Level 4
#
# The password for the next level is stored in a hidden file in the inhere directory.

# %% [markdown]
# - First, we need to naviagate the `inhere` directory

# %%
cd inhere

# %% [markdown]
# - Apparently, the directory returns no files. This is a bit sus, so we need to invoke the following command to show the hidden files and its corresponding details if there are any

# %%
ls -la

# %% [markdown]
# - Now, we have found 1 hidden file

# %%
drwxr-xr-x 2 root    root    4096 Oct 14 09:26 .
drwxr-xr-x 3 root    root    4096 Oct 14 09:26 ..
-rw-r----- 1 bandit4 bandit3   33 Oct 14 09:26 ...Hiding-From-You

# %% [markdown]
# - Reading the content of the file reveals the password for the next level

# %%
2WmrDFRmJIq3IPxneAaMGhap0pFhF3NJ
