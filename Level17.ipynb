# %% [markdown]
# ## Bandit Level 17 → Level 18
#
# There are 2 files in the homedirectory: passwords.old and passwords.new. The password for the next level is in passwords.new and is the only line that has been changed between passwords.old and passwords.new
#
# NOTE: if you have solved this level and see ‘Byebye!’ when trying to log into bandit18, this is related to the next level, bandit19

# %% [markdown]
# - From the previous level we were provided with the `RSA security key`. To use this, I saved it into a text file and used the same mechanism to login on `Level 13`

# %%
ssh -i b17_password.txt -p 2220 bandit17@bandit.labs.overthewire.org

# %% [markdown]
# - To compare the difference between two files, we can use the `diff` command

# %%
diff passwords.old passwords.new

# %% [markdown]
# - This outputs:

# %%
42c42
< BMIOFKM7CRSLI97voLp3TD80NAq5exxk
---
> x2gLTTjFwMOhQ8oWNbMN362QKxfRqGlO

# %% [markdown]
# - We need the latter for this one, as this is the 'password' for the next level
