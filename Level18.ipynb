# %% [markdown]
# ## Bandit Level 18 → Level 19
#
# The password for the next level is stored in a file readme in the homedirectory. Unfortunately, someone has modified .bashrc to log you out when you log in with SSH.

# %% [markdown]
# - Trying to login using the password yielded from the previous level resulted to exiting the `ssh` due to added command on the `.bashrc` script. Thus, we need to employ a kinda `shell within a shell`

# %%
ssh -p 2220 bandit18@bandit.labs.overthewire.org 'ls -l'

# %% [markdown]
# - This outputs:

# %%
-rw-r----- 1 bandit19 bandit18 33 Oct 14 09:26 readme

# %% [markdown]
# - It turns out there is a readme file. Now, let's try reading its content

# %%
ssh -p 2220 bandit18@bandit.labs.overthewire.org 'cat readme'

# %% [markdown]
# - Now, it gives the password for the next level

# %%
cGWpMaKXVwDUNgPAVJbWYuGHVn9zl3j8
