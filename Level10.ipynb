# %% [markdown]
# ## Bandit Level 10 → Level 11
#
# - The password for the next level is stored in the file data.txt, which contains base64 encoded data

# %% [markdown]
# - This is an easy one. We just need to decrypt the content of `data.txt` using the `base64` command

# %%
base64 -d data.txt

# %% [markdown]
# - The `-d` flag stands for decode. After executing the command above, we are presented with this

# %%
The password is dtR173fZKb0RRsDFSGsg2RWnpNVj3qRr

# %% [markdown]
# Thus, the password to unlock the next level is

# %%
dtR173fZKb0RRsDFSGsg2RWnpNVj3qRr
