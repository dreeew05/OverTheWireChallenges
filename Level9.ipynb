# %% [markdown]
# ## Bandit Level 8 → Level 9
#
# - The password for the next level is stored in the file data.txt and is the only line of text that occurs only once

# %% [markdown]
# - To do this, we need to utilize the `uniq` command to filter out the text that only occures once. However, since the said command only detects and removes lines that are immeadiately next to each other, we also need to use `sort`

# %%
sort data.txt | uniq -u

# %% [markdown]
# - The `-u` flag prints only lines that are truly unique. After running the command, we are presented with the password for the next level

# %%
4CKMh1JI91bUIZZPXDqGanal4xvAg0JM
